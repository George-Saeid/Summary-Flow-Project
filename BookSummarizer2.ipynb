# %%
import os
from BookSpliter import split_book
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# %%
# Load Pegasus Model & Tokenizer
model_checkpoint = 'pegasus_summaryflow_model'
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoint)
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
# Summarize the book recursively
def summarize_book(book):
    # Split the book into paragraphs
    splited_book = split_book(book)
    if len(splited_book) <= 10: # Base case
        result_book = "\n".join(splited_book)
        return result_book
    else:
        summary_list = []
        for i in range(len(splited_book)): # Loop through all paragraphs to generate summaries
            # Tokenize the input text
            inputs = tokenizer(splited_book[i], return_tensors="pt", max_length=1024, truncation=True)
            # Generate summary
            summary_ids = model.generate(inputs.input_ids.to(model.device))
            # Decode the summary tokens
            summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
            # Add to summary list
            summary_list.append(summary)
        # Combine all summarise into a single paragraph
        summarized_book = "\n".join(summary_list)
        # Recursively summarize the generated book
        print('A level is summarized successfully!!')
        print('Summarized book : ')
        print(summarized_book)
        return summarize_book(summarized_book)

# %%
def save_summary(book_name, summary):
    # Create a folder named "Summaries" if it doesn't already exist
    summaries_folder = r"D:\Gethub\SummaryFlow\Summaries"
    os.makedirs(summaries_folder, exist_ok=True)

    # Generate the file path for the summary text file
    summary_file_path = os.path.join(summaries_folder, book_name + " summary.txt")

    # Write the final summary to the text file
    with open(summary_file_path, 'w', encoding='utf-8') as f:
        f.write(summary)

# %%
# Try to summarize known book

# Take the book path
book_path = r"D:\Gethub\SummaryFlow\WholeNovels\Debt of Honor.txt"

# Read the book from the pdf file
with open(book_path, 'r') as file:
    # Read the entire contents of the file into a string
    book = file.read()

# Summarize the book and print it 
final_summary = summarize_book(book)
print("Final Book Summary : ")
print(final_summary)

# Save the summary to a text file
book_name = "The Alchemist"
save_summary(book_name, final_summary)
# Out:
# Splited successfully !!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 12
#       9     book = file.read()
#      11 # Summarize the book and print it
# ---> 12 final_summary = summarize_book(book)
#      13 print("Final Book Summary : ")
#      14 print(final_summary)
#
# Cell In[16], line 14, in summarize_book(book)
#      12 inputs = tokenizer(splited_book[i], return_tensors="pt", max_length=1024, truncation=True)
#      13 # Generate summary
# ---> 14 summary_ids = model.generate(inputs.input_ids.to(model.device))
#      15 # Decode the summary tokens
#      16 summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\generation\utils.py:1558, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1551     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1552         input_ids=input_ids,
#    1553         expand_size=generation_config.num_beams,
#    1554         is_encoder_decoder=self.config.is_encoder_decoder,
#    1555         **model_kwargs,
#    1556     )
#    1557     # 13. run beam search
# -> 1558     return self.beam_search(
#    1559         input_ids,
#    1560         beam_scorer,
#    1561         logits_processor=prepared_logits_processor,
#    1562         stopping_criteria=prepared_stopping_criteria,
#    1563         pad_token_id=generation_config.pad_token_id,
#    1564         eos_token_id=generation_config.eos_token_id,
#    1565         output_scores=generation_config.output_scores,
#    1566         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1567         synced_gpus=synced_gpus,
#    1568         **model_kwargs,
#    1569     )
#    1571 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1572     # 11. prepare logits warper
#    1573     logits_warper = self._get_logits_warper(generation_config)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\generation\utils.py:2942, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2938         break
#    2940 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 2942 outputs = self(
#    2943     **model_inputs,
#    2944     return_dict=True,
#    2945     output_attentions=output_attentions,
#    2946     output_hidden_states=output_hidden_states,
#    2947 )
#    2949 if synced_gpus and this_peer_finished:
#    2950     cur_len = cur_len + 1
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\models\bart\modeling_bart.py:1731, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1726     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1727         decoder_input_ids = shift_tokens_right(
#    1728             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1729         )
# -> 1731 outputs = self.model(
#    1732     input_ids,
#    1733     attention_mask=attention_mask,
#    1734     decoder_input_ids=decoder_input_ids,
#    1735     encoder_outputs=encoder_outputs,
#    1736     decoder_attention_mask=decoder_attention_mask,
#    1737     head_mask=head_mask,
#    1738     decoder_head_mask=decoder_head_mask,
#    1739     cross_attn_head_mask=cross_attn_head_mask,
#    1740     past_key_values=past_key_values,
#    1741     inputs_embeds=inputs_embeds,
#    1742     decoder_inputs_embeds=decoder_inputs_embeds,
#    1743     use_cache=use_cache,
#    1744     output_attentions=output_attentions,
#    1745     output_hidden_states=output_hidden_states,
#    1746     return_dict=return_dict,
#    1747 )
#    1749 lm_logits = self.lm_head(outputs[0])
#    1750 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\models\bart\modeling_bart.py:1617, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1610     encoder_outputs = BaseModelOutput(
#    1611         last_hidden_state=encoder_outputs[0],
#    1612         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1613         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1614     )
#    1616 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1617 decoder_outputs = self.decoder(
#    1618     input_ids=decoder_input_ids,
#    1619     attention_mask=decoder_attention_mask,
#    1620     encoder_hidden_states=encoder_outputs[0],
#    1621     encoder_attention_mask=attention_mask,
#    1622     head_mask=decoder_head_mask,
#    1623     cross_attn_head_mask=cross_attn_head_mask,
#    1624     past_key_values=past_key_values,
#    1625     inputs_embeds=decoder_inputs_embeds,
#    1626     use_cache=use_cache,
#    1627     output_attentions=output_attentions,
#    1628     output_hidden_states=output_hidden_states,
#    1629     return_dict=return_dict,
#    1630 )
#    1632 if not return_dict:
#    1633     return decoder_outputs + encoder_outputs
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\models\bart\modeling_bart.py:1470, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1457     layer_outputs = self._gradient_checkpointing_func(
#    1458         decoder_layer.__call__,
#    1459         hidden_states,
#    (...)
#    1467         use_cache,
#    1468     )
#    1469 else:
# -> 1470     layer_outputs = decoder_layer(
#    1471         hidden_states,
#    1472         attention_mask=attention_mask,
#    1473         encoder_hidden_states=encoder_hidden_states,
#    1474         encoder_attention_mask=encoder_attention_mask,
#    1475         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1476         cross_attn_layer_head_mask=(
#    1477             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1478         ),
#    1479         past_key_value=past_key_value,
#    1480         output_attentions=output_attentions,
#    1481         use_cache=use_cache,
#    1482     )
#    1483 hidden_states = layer_outputs[0]
#    1485 if use_cache:
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\anaconda3\envs\NN\Lib\site-packages\transformers\models\bart\modeling_bart.py:796, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     794 # Fully Connected
#     795 residual = hidden_states
# --> 796 hidden_states = self.activation_fn(self.fc1(hidden_states))
#     797 hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
#     798 hidden_states = self.fc2(hidden_states)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File d:\anaconda3\envs\NN\Lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
